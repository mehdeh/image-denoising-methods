# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab/diffusion/edm/my_utils
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab/diffusion/edm/my_utils

# %%
from edm_denoiser_gradient import run_denoiser_demo
run_denoiser_demo()
# Out:
# project_dir: /content/drive/MyDrive/Colab/diffusion/edm
# Using device: cpu
#
# Loading model from local path: ./pretrain_models/edm-cifar10-32x32-uncond-ve.pkl
# Loaded test images shape: torch.Size([4, 3, 32, 32])
# Original input (clean) images:
# Noisy inputs:
# Iteration 1:
#   Norm2 of grad_x_log_pdf_value = tensor([18.5993, 18.0028, 18.3832, 18.2348], dtype=torch.float64)
#   Showing updated x_cur images:
#   Showing denoised x_cur images:
# Iteration 2:
#   Norm2 of grad_x_log_pdf_value = tensor([16.5673, 16.0217, 16.3596, 16.2402], dtype=torch.float64)
#   Showing updated x_cur images:
#   Showing denoised x_cur images:
# Iteration 3:
#   Norm2 of grad_x_log_pdf_value = tensor([14.7601, 14.2591, 14.5568, 14.4624], dtype=torch.float64)
#   Showing updated x_cur images:
#   Showing denoised x_cur images:
# Iteration 4:
#   Norm2 of grad_x_log_pdf_value = tensor([13.1616, 12.6938, 12.9558, 12.8832], dtype=torch.float64)
#   Showing updated x_cur images:
# ...
